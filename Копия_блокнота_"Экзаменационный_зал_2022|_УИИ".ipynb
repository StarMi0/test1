# %% [markdown]
# <a href="https://colab.research.google.com/github/StarMi0/test1/blob/main/%D0%9A%D0%BE%D0%BF%D0%B8%D1%8F_%D0%B1%D0%BB%D0%BE%D0%BA%D0%BD%D0%BE%D1%82%D0%B0_%22%D0%AD%D0%BA%D0%B7%D0%B0%D0%BC%D0%B5%D0%BD%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D0%B9_%D0%B7%D0%B0%D0%BB_2022%7C_%D0%A3%D0%98%D0%98%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Загрузить билеты

import random
Python_questions = [
    'Встроенные типы данных Python. Функция type(). Приведение типов.',
    'Условный оператор.',
    'Арифметические и логические операции.',
    'Коллекции данных: типы tuple, list, dict.',
    'Переменные Python. Правила именования переменных.',
    'Циклы for и while.',
    'Функции ввода/вывода данных Python (print(), input()).',
    'Пользовательские функции. Параметры функций.',
    'Библиотека Numpy. Индексация. Срезы.',
    'Библиотека Numpy. Модуль random.',
    'Библиотека Matplotlib. Методы .plot(), .bar(), .gist().',
    'Модули. Модуль os.',
    'Работа с файлами. Функция open(). Контекстный менеджер with.',
    'Библиотека Pandas. Базовые методы.',
    'Библиотека Pandas. Статистические методы.',
    'Циклы for и while.',
    'Функции ввода/вывода данных Python (print(), input()).',
    'Пользовательские функции. Параметры функций.',
    #'Последовательность шагов при создании веб-сервера. (16)',
    #'REST API. (17)',
    #'Fast API. (18)',
]
random.shuffle(Python_questions)

DS_l_questions = [
    'Активационные функции',
    'Функция ошибки. Стандартные функции ошибок keras',
    'Оптимизаторы. Стандартные оптимизаторы keras',
    'Обучение нейронной сети. Выборки. Валидация данных',
    'Задача классификации. Формирование выборки, особенности построения архитектур НС',
    'Переобучение нейронной сети. Причины. Способы борьбы',
    'Особенности построения моделей с помощью Sequential и FunctionalAPI',
    'Линейный слой Dense. Устройство слоя',
    'Сверточный слой Conv2D. Основные параметры слоя',
    'Pooling-слои',
    'Tokenizer. Применение, основные параметры',
    'Параметризация текста BagOfWords',
    'Embedding-слой. Основные параметры слоя',
    'Задач регрессии. Примеры. Подготовка данных, принцип построения архитектур НС для решения задачи',
    'Временный ряды. Инструмент TimeSeriesGenerator. Особенности формирования выборки',
    'Аугментация изображений. Инструмент ImageDataGenerator',
    'Устройство автокодировщика. Области применения и недостатки подхода',
    'Способы сохранения/загрузки модели нейронной сети',
]
random.shuffle(DS_l_questions)

DS_h_questions = [
    'Архитектура Вариационных автокодировщиков. Ошибка Кульбака-Лейблера.',
    'Инструмент Callback’ов. Встроенные Callback’и keras’а.',
    'Архитектура U-Net. Принцип построения.',
    'Задача сегментации изображений. Формирование выборки.',
    'Задача кластеризации. Алгоритм Kmean.',
    'Задача кластеризации. Алгоритм Kmean.',
    'Рекуррентные нейронные сети. Слой LSTM.',
    'Устройство GAN.',
    'Устройство GAN.',
    'GAN с условием.',
    #'Основные принципе алгоритма Q-learning.',
    #'Основные принципе алгоритма Police Gradient.',
    'Архитектура SequenceToSequence. Принцип построения.',
    'Архитектура SequenceToSequence. Принцип построения.',
    #'Сети с вниманием. Основные преимущества по сравнению с моделью seq2seq.',
    'Обнаружение объектов. Принцип построения архитектуры YOLO.',
    'Параметризация аудио. Основные фичи, извлекаемые из аудиофайла.',
    'Базовые принципы генетического алгоритма.',
    'Базовые принципы генетического алгоритма.',
    'Подбор гиперпараметров нейронной сети с помощью генетического алгоритма.',
    #'Распознавание речи. Метрика WER.',
    #'Синтез речи. Конкатенативный и параметрический подходы. Библиотеки синтеза речи.',
]
random.shuffle(DS_h_questions)

Tensors = [
    '<pre><br>inp = Input(shape=(10, 128))<br>x = Conv1D (16, (2), padding="valid") (inp)<br>x = LSTM (32, return_state=True, return_sequences=True) (x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(128, 128, 3))<br>x = Dense(128, activation="relu") (inp)<br>x = Conv2D(32, (2,2), activation="softmax") (x)<br>x = Conv2D(64, (2,2), activation="softmax") (x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(12, 64))<br>x = Dense(128, activation="tanh") (inp)<br>x = Dense(3, activation="softmax") (x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(128, 128, 3,))<br>x = Dense(128) (inp)<br>x = Conv2D(32, (3, 4), activation="softmax") (x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(256, 128, 3))<br>x = Conv2D(32, (2,2), strides=(2,2), activation="relu", padding="same") (inp)<br>x = Conv2D(64, (2,2), strides=(2,2), activation="relu", padding="same") (x)<br>x = Conv2D(128, (2,2), strides=(2,2)) (x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(77, 77))<br>x = Conv1D(32, (2), activation="relu", padding="same") (inp)<br>x = Dense(64, activation="sigmoid")(x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(16, 16, 1))<br>x = Conv2D(8, (2,2), activation="relu", padding="same") (inp)<br>x = Conv2D(2, (2,2), strides=(2,2), activation="relu", padding="same") (x)<br>x = Flatten()(x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(128, 128, 3))<br>x = Conv2D(32, (4,4), activation="relu", padding="same") (inp)<br>x = MaxPool2D()(x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(100))<br>x = Embedding(100, 200)(inp)<br>x = LSTM(30, activation="relu") (x)<br>x = Dense(1, activation="sigmoid") (x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(35))<br>x = Embedding(100, 200)(inp)<br>x = Dense(1, activation="sigmoid") (x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(100))<br>x = Embedding(70, 200)(inp)<br>x = LSTM(20, activation="sigmoid") (x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(100))<br>x = Embedding(70, 200)(inp)<br>x = LSTM(20, return_sequences=True, activation="sigmoid") (x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(100))<br>x = Embedding(150, 200)(inp)<br>x = LSTM(100, return_state=True, activation="softmax") (x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(20,100))<br>x = Embedding(150, 200)(inp)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(16,16))<br>x = Dense(1, activation="relu")(inp)<br>x = Conv1D(10, (1), activation="softmax")(x)<br>x = Flatten()(x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(100,1))<br>x = Conv1D(5, (10), activation="softmax", padding="same")(inp)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(32,32))<br>x = Dense(32)(inp)<br>x = Flatten()(x)<br>x = Dense(64)(x)<br>model = Model(inp, x)</pre>',
    '<pre><br>inp = Input(shape=(32,32,3))<br>x = Conv2D(32, (2,2), activation="softmax", padding="same")(inp)<br>y = Flatten()(x)<br>model = Model(inp, x)</pre>',
]
random.shuffle(Tensors)



index = '''
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta http-equiv="X-UA-Compatible" content="IE=edge">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <link rel="stylesheet" href="./nbextensions/google.colab/style.css" media="screen">
  <title>Document</title>
</head>
<body>
	<div class="divtitle"> УНИВЕРСИТЕТ ИСКУССТВЕННОГО ИНТЕЛЛЕКТА </div>
	<div class="divsubtitile"> Экзаменационный зал </div>
	<hr>
	<div class="maket"> <br>
	</div>
	<hr>
	<div class="divfooter"> 2022г. </div>
<script src='./nbextensions/google.colab/jquerymin.js'></script>
<script  src="./nbextensions/google.colab/script.js"></script>
</body>
</html>
'''

css = '''
@font-face {
  font-family: 'Roboto',Arial,sans-serif;
  src: url('../fonts/soft_bold.woff2') format('woff2');
  src: url('../fonts/soft_bold.woff') format('woff2');
  font-weight: 900;
}



*, h1 {
  box-sizing: border-box;
  margin: 0;
  padding: 0;
}

:root {
  --height-cards: 3;
}

li {
  list-style-type: none;
}

body {
  //background-color: royalblue;
  font-family: 'Roboto',Arial,sans-serif;
  text-align: center;
}

pre{
  margin-left: 10%;
  font-family: "Courier", sans-serif;
}
input::-webkit-outer-spin-button,
input::-webkit-inner-spin-button {
    -webkit-appearance: none;
    margin: 0;
}




.container {
  position: relative;
  max-width: 1140px;
  margin: auto;
  display: flex;
  justify-content: center;
  flex-direction: column;
}

.memoryGame__list {
  display: flex;
  flex-wrap: wrap;
  width: 800px;
  height: 1000px;
  margin: auto;
  perspective: 1000px;

}

.memoryGame__card {
  margin: 10px;
}

.card {
  position: relative;
  width: 14%;
  height: 180px;
  box-shadow: 5px 5px 5px rgba(11, 99, 172, 0.753);
  border: none;
  transform: scale(1);
  border-radius: 10px;
  transform-style: preserve-3d;
  transition: transform 0.5s;
  display: inline-block;
  font-size: 6px;
}

.card:active {
  transform: scale(0.95);
  transition: transform .2s;
}



.card__front,
.card__back {
  position: absolute;
  height: 100%;
  width: 100%;
  padding: 5%;
  border-radius: 10px;
  backface-visibility: hidden;
}

.card__back{
  font-size: 16px;
  font-weight: 400;
  padding-top: 70px;
  background-color: rgb(220, 220, 220);
  cursor: pointer;
}

.card__front {
  text-align: left;
  letter-spacing: 1px;
  font-weight: 400;
  padding: 20px;
  background-color: rgb(240, 240, 240);
  transform: rotateY(180deg);
  object-fit: cover;
  cursor: pointer;
}


.card__flip {
	position: absolute;
	z-index: 100;
	left: 10%;
	bottom: 20%;
	width: 80%;
	height: 50%;
	font-size: 100%;
    transform: rotateY(180deg);
}

.card_resize {
	#animation-duration: 1s;
    #animation-name: slidein;
	position: absolute;
	z-index: 100;
	transition: transform 1s;
	transform: rotateY(180deg);
	transform: translateX(300px);
}

.card_max{
	left: 10%;
	font-size: 100%;
	height: 50%;
	width: 80%;
	bottom: 20%;
}


@keyframes slidein {
  from {
    left: var(--left);
  }

  to {
	left: 10%;
	#font-size: 100%;
	#height: 50%;
	#width: 80%;
	#bottom: 20%;
  }

}

.divtitle{
    font-weight: 600;
    color: #000;
    letter-spacing: 2.5px;
	  padding-top: 30px;
    padding-bottom: 22px;
}

.divfooter{
    font-weight: 600;
    color: #000;
    letter-spacing: 2.5px;
	  padding-top: 30px;
    padding-bottom: 22px;
}

.divsubtitile{
	  padding-top: 2px;
    padding-bottom: 30px;
	  font-size: 36px;
    line-height: 1.23;
    font-weight: 600;
    color: #000;
}

.maket{
  font-size: 20px;
	letter-spacing: 2.5px;
	padding-top: 10px;
  padding-bottom: 10px;
}

.bilet{
	  position: relative;
    display: inline-block;
    margin: 1em;
    opacity: .7;
    width: 17%;
	  height:160px;
    border-radius: 5px;
    background: #E4E1E4;
    -webkit-perspective: 400px;
    perspective: 400px;
    -webkit-transform-style: preserve-3d;
    transform-style: preserve-3d;
}

.hide{
  display: none;
}
'''
script = '''
/*
Reference: http://jsfiddle.net/BB3JK/47/
*/
$( document ).ready(function() {
    var Python_questions = [' ''' + "','".join(Python_questions) + '''']
    var DS_l_questions = [' ''' + "','".join(DS_l_questions) + '''']
    var DS_h_questions = [' ''' + "','".join(DS_h_questions) + '''']
    var Tensors = [' ''' + "','".join(Tensors) + '''']
    const maket = document.querySelector('.maket');
    const TICKET_CNT = 18;
    function mainMenu() {
      lockBoard = false;

      for (let i = 1; i < TICKET_CNT+1; i++) {
        el1 = document.createElement('div');
        el1.classList.add('memoryGame__card', 'card')

        els1 = document.createElement('div');
        els1.classList.add('card__front')
        els1.innerHTML += '<h3> БИЛЕТ №' + i.toString()  + "</h3><br><br>"
		+ '1. ' + Python_questions[i-1] + "<br><br>"
        + '2. ' + DS_l_questions[i-1] + "<br><br>"
        + '3. ' + DS_h_questions[i-1] + "<br><br>"
        + "4. Размерности. Что выведет model.summary() для модели:<br> " + Tensors[i-1];

        els2 = document.createElement('div');
        els2.classList.add('card__back')
        els2.innerHTML += '<b>Билет №' + i.toString() + '</b><br>УИИ';


        el1.append(els1, els2);
        maket.append(el1);

        el1.addEventListener('click',  flipCard)
      }

     function flipCard(elem) {
		console.log(elem.currentTarget);
        if (lockBoard) return;
		var el = elem.currentTarget;
        el.classList.add('card__flip');
		lockBoard = true;
        //setTimeout(() => {
          //console.log(el);
		  //el.classList.add('card_resize');
        //}, 700);
		//setTimeout(() => {
//          console.log(el);
		  //el.classList.add('card_max');
        //}, 1000);

        }
  }
    mainMenu();
});


'''

with open('index.html', 'w') as f:
  f.write(index)

with open('/usr/local/share/jupyter/nbextensions/google.colab/style.css', 'w') as f:
  f.write(css)

with open('/usr/local/share/jupyter/nbextensions/google.colab/script.js', 'w') as f:
  f.write(script)

import gdown
gdown.download('https://storage.yandexcloud.net/aiueducation/temp/jquerymin.js', '/usr/local/share/jupyter/nbextensions/google.colab/jquerymin.js', True)

from IPython.display import HTML
HTML('index.html')
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <link rel="stylesheet" href="./nbextensions/google.colab/style.css" media="screen">
#   <title>Document</title>
# </head>
# <body>
# 	<div class="divtitle"> УНИВЕРСИТЕТ ИСКУССТВЕННОГО ИНТЕЛЛЕКТА </div>
# 	<div class="divsubtitile"> Экзаменационный зал </div>
# 	<hr>
# 	<div class="maket"> <br>
# 	</div>
# 	<hr>
# 	<div class="divfooter"> 2022г. </div>
# <script src='./nbextensions/google.colab/jquerymin.js'></script>
# <script  src="./nbextensions/google.colab/script.js"></script>
# </body>
# </html>
